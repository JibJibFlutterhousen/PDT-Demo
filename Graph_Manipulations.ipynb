# %%
import os
import sys
import networkx as nx
import matplotlib.pyplot as plt

# Add the root of your project to the sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), 'graph-manipulation')))

from source import graph_utilities

# %%
file_path = os.path.join(os.getcwd(), 'Zim_Graph', 'figure.tikz')
graph, layout = graph_utilities.load_tikz(file_path)
nx.draw(graph, pos=layout, with_labels=True)

# %%
file_path = os.path.join(os.getcwd(), 'Modified_NE', 'figure.tikz')
graph, layout = graph_utilities.load_tikz(file_path)
nx.draw(graph, pos=layout, with_labels=True)

# %%
file_path = os.path.join(os.getcwd(), 'Small_graphs', 'graph3c.g6')
graphs = [graph for graph in graph_utilities.graph6_file_iterator(file_path)]
for graph in graphs:
    nx.draw_kamada_kawai(graph, with_labels=True)
    plt.show()
    plt.close()

# %%
file_path = os.path.join(os.getcwd(), 'Small_graphs')
graphs = [graph for graph in graph_utilities.directory_g6_iterator(file_path)]
for graph in graphs:
    nx.draw_kamada_kawai(graph, with_labels=True)
    plt.show()
    plt.close()
